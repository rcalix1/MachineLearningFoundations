# %%
# Optimize prompts by training on prompts-ratings pairings dataset
# taken from https://github.com/JD-P/simulacra-aesthetic-captions

import os
import sqlite3
from urllib.request import urlretrieve

# %%
## from accelerate import Accelerator

# %%
## import trlx
## from trlx.data.default_configs import default_ilql_config

# %%
url = "https://raw.githubusercontent.com/JD-P/simulacra-aesthetic-captions/main/sac_public_2022_06_29.sqlite"

dbpath = "sac_public_2022_06_29.sqlite"

# %%
## accelerator = Accelerator()

if os.environ.get("LOCAL_RANK", "0") == "0" and not os.path.exists(dbpath):
    print(f"fetching {dbpath}")
    urlretrieve(url, dbpath)

## accelerator.wait_for_everyone()

# %%
conn = sqlite3.connect(dbpath)
c = conn.cursor()
c.execute(
    "SELECT prompt, rating FROM ratings "
    "JOIN images ON images.id=ratings.iid "
    "JOIN generations ON images.gid=generations.id "
    "WHERE rating IS NOT NULL;"
)

# %%
prompts, ratings = tuple(map(list, zip(*c.fetchall())))

# %%
prompts
# Out:
# ['An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'an optimistic full color hd poster of happy uncle sam laying out a cornucopia of red white and blue pills',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'an organic and detailed design for a cryonics preservation chamber',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'An artwork of a broken wine bottle in the medium of dry pigments',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'A crystal apple from the angel of crystaline',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'a once in a lifetime miracle experienced during the dreamtime, matte painting, trending on artstation',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'The below fantasies spell of crystal hearts breakage',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'DSLR POV shot looking down from the rooftop of a skyscraper onto whirs of light as the cars zip by on the street below',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'Black blaze, the stars of gods takes place to ignite',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'tense atmosphere in the SpaceX control room as mission control scientists and engineers countdown to a blastoff launch',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'Lush heaven, great perception of the vows on the cold symphonies',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'strains of strings, things of sacrifices bleeds through flowers',
#  'a purple violin squealing terrible notes',
#  'a purple violin squealing terrible notes',
#  'a purple violin squealing terrible notes',
#  'a purple violin squealing terrible notes',
#  'a purple violin squealing terrible notes',
#  'a purple violin squealing terrible notes',
#  'a purple violin squealing terrible notes',
#  'a purple violin squealing terrible notes',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'a maximalist detailed cyberpunk tokyo city street scene of a race car drifting a corner by trending on artstation',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'The clouds filled with the heart of constellation by gods of works',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'winter wonderland in the plains below the gorgeous mountains',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'The shattered star in the nigh time of winter wind',
#  'a snow covered road at night next to a forest of pine trees',
#  'a snow covered road at night next to a forest of pine trees',
#  'a snow covered road at night next to a forest of pine trees',
#  'a snow covered road at night next to a forest of pine trees',
#  'a snow covered road at night next to a forest of pine trees',
#  'a snow covered road at night next to a forest of pine trees',
#  'a snow covered road at night next to a forest of pine trees',
#  'a snow covered road at night next to a forest of pine trees',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'illustration of spreadsheet hauntology, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'dynamism of a time machine, trending on artstation',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'connect and interconnect, starts of the moon of two worlds',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'sleeping on a cloud drifting over the fields and rivers',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'touch of the continuous burns of the images of wills',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'a man undergoing bionic cyborg augmentation in a surgery theater by leonardo da vinci',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'Roses under reds of souls, time worth a break in space of none',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'an illustration of a psychedelic chemistry lab in bursting high resolution colors by ross tran',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'dance of perfection, call such vivid, death is next to such promise of yours',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'machine elves building a dyson sphere in the style of  Diego Rivera\'s "Man, Controller of the Universe"',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  'the psychedelic carnival will be starting soon, buy your tickets here',
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  "night of the ophanim is a painting featuring the angel's heavenly interlocking Gemma's astronomical Equinoctal sundial rings concentric wheels engraved with eyes, featured on artstation",
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'A Buddhist Monk Using An EEG Brain-Computer-Interface Cap To Exorcise The Hungry Ghost In An Unenlightened Person, trending on artstation',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'elevate the events of cuts of strings in the living gods on things of lies ties',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  'a bodhisattva meditating in the center of a cyberdelic control room monitors televisions screens computers hacker lab, concept art, matte painting, trending on artstation',
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  "stones of eyes in color of hue's of hunts and colors",
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'vedic dissidents retreating to an online digital cyberdelic forest to meditate on the future of mankind, trending on artstation',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'shiva standing at the center of a swirling vortex ushering forth the technological singularity',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'thoughts of vivid, on such such vivid in spreading shadows in conscious',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'A retrofuturistic Indian market stalls booths assembled around a train track going through its center, acrylic on canvas by ross tran',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'brilliance on rails on stars of stages of movements, actions then death',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'a shuttle leaving a streak of light as it charges through a large rail tunnel with rings of light along its edges',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'The angels suffering on death concious bleakness, decay all cores in space of ours',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'waits and weighs, while power of strikes dent the world so called souls',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'a raver dancing in an elevator party with a DJ and bar, matte painting',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'Matters of starres, things like living makes such dazes on darkness',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'construction workers building the empire state building in the style of socialist realism',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'starve to missing flowers of puzzles of my working heart',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a cat and a dog in a boxing match, oil on canvas',
#  'a chorus of angels surrounding a sword in the stone',
#  'a chorus of angels surrounding a sword in the stone',
#  'a chorus of angels surrounding a sword in the stone',
#  'a chorus of angels surrounding a sword in the stone',
#  'a chorus of angels surrounding a sword in the stone',
#  'a chorus of angels surrounding a sword in the stone',
#  'a chorus of angels surrounding a sword in the stone',
#  'a chorus of angels surrounding a sword in the stone',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'A Japanese relic of a soul trapper',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a bodega convenience store aisle with shelves of fine merchandise, matte painting',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a realistic treasure chest full of gold coins',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'a skull filled with dandelions',
#  'A crystal heart',
#  'A crystal heart',
#  'A crystal heart',
#  'A crystal heart',
#  'A crystal heart',
#  'A crystal heart',
#  'A crystal heart',
#  'A crystal heart',
#  'A crystal heart',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'extremely colorful fireworks exploding over the puget sound, matte painting',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'A japanese ink drawing of a dead man in a flower field',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'illustrated portrait of john von neumann in front of an electronic computer, trending on artstation',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'A watercolor painting of a broken lightbulb',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'a geeky nerd man wearing AR alternate reality glasses standing with his arms crossed in a translucent sheen of turquoise fog, trending on artstation',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'A vintage picture of the angels of deaths in the field of water, taken with a oqi-781',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'the demon core, oil on canvas',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'A propaganda style poster of a red butterfly',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'beautiful industrial interior of a nuclear fusion plant, matte painting',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'the swamp fog forests on the surface of venus, the venusian retrofuturist frontier by ross tran and halo',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
#  'A pencil sketch of the death garden in Newyork',
# ...
#  'seagulls picking apart a rotting fish, shadertoy rtx on',
#  'seagulls picking apart a rotting fish, shadertoy rtx on',
#  'seagulls picking apart a rotting fish, shadertoy rtx on',
#  'seagulls picking apart a rotting fish, shadertoy rtx on',
#  'seagulls picking apart a rotting fish, shadertoy rtx on',
#  'seagulls picking apart a rotting fish, shadertoy rtx on',
#  'seagulls picking apart a rotting fish, shadertoy rtx on',
#  'a fluffy pick teddy bear',
#  'a fluffy pick teddy bear',
#  'a fluffy pick teddy bear',
#  'a fluffy pick teddy bear',
#  'a fluffy pick teddy bear',
#  'a fluffy pick teddy bear',
#  'a fluffy pick teddy bear',
#  'a fluffy pick teddy bear',
#  'a fluffy pink teddy bear',
#  'a fluffy pink teddy bear',
#  'a fluffy pink teddy bear',
#  'a fluffy pink teddy bear',
#  'a fluffy pink teddy bear',
#  'a fluffy pink teddy bear',
#  'a fluffy pink teddy bear',
#  'a fluffy pink teddy bear',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'an aquarium fireplace, the aquarium fireplace, trending on artstation anime illustration',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a shadow man standing in the corner of my room wearing a fancy hat',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'a rocket ship speeding towards venus, trending on artstation',
#  'the angel of eternal life',
#  'the angel of eternal life',
#  'the angel of eternal life',
#  'the angel of eternal life',
#  'the angel of eternal life',
#  'the angel of eternal life',
#  'the angel of eternal life',
#  'the angel of eternal life',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'crystalline entity of the 4th dimension',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of a royal family',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'oil on canvas painting of the war of 1812',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'an old painting of a knight in shining armor',
#  'a confused duck',
#  'a confused duck',
#  'a confused duck',
#  'a confused duck',
#  'a confused duck',
#  'a confused duck',
#  'a confused duck',
#  'a confused duck',
#  'a confused duck',
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  "a photograph of batman's tea party",
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'a castle in the clouds',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'dancing in the waves',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'a photograph of a steak dinner with a side of asparagus',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'blessings from the holy prophet of muffins',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'professional portrait of a corgi',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'a roast beef sandwich on ciabatta bread with arugula and horseradish sauce',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'artisanal cold brew coffee setup, 5 stars on yelp',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'a man shaving his beard in a mirror, advertisement for cool menthol shaving cream',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The spaghetti was undercooked and the beans were cold. 2/5, would not come back',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'The Adagio Apartment homes, opening Fall 2023, urban living in style',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'a cozy cabin next to a domestic nuclear reactor, matte painting',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'The boxing match went on for 4 hours',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'dark fantasy cheeseburger',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'a portrait of a young woman distressed by finances by mandy jurgens',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'whatever have we done? The painters know not their strength',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'destruction begets destruction',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'street scene of a cyberpunk Tokyo market stall, artstation matte painting',
#  'the underlying problem',
#  'the underlying problem',
#  ...]

# %%
ratings
# Out:
# [7,
#  1,
#  4,
#  6,
#  6,
#  5,
#  6,
#  2,
#  3,
#  6,
#  1,
#  5,
#  3,
#  2,
#  6,
#  5,
#  4,
#  7,
#  3,
#  1,
#  6,
#  5,
#  5,
#  4,
#  2,
#  6,
#  3,
#  3,
#  4,
#  5,
#  7,
#  4,
#  4,
#  2,
#  3,
#  2,
#  6,
#  5,
#  6,
#  6,
#  5,
#  6,
#  6,
#  6,
#  5,
#  2,
#  4,
#  3,
#  5,
#  3,
#  6,
#  5,
#  7,
#  1,
#  1,
#  1,
#  1,
#  3,
#  3,
#  2,
#  5,
#  1,
#  5,
#  1,
#  3,
#  6,
#  6,
#  4,
#  6,
#  5,
#  4,
#  3,
#  1,
#  7,
#  6,
#  5,
#  6,
#  7,
#  5,
#  4,
#  2,
#  2,
#  3,
#  7,
#  3,
#  4,
#  4,
#  6,
#  1,
#  5,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  3,
#  7,
#  6,
#  5,
#  5,
#  5,
#  7,
#  4,
#  1,
#  3,
#  3,
#  2,
#  3,
#  4,
#  3,
#  3,
#  7,
#  3,
#  4,
#  5,
#  6,
#  7,
#  6,
#  5,
#  3,
#  4,
#  2,
#  1,
#  3,
#  1,
#  1,
#  1,
#  2,
#  5,
#  1,
#  5,
#  5,
#  6,
#  5,
#  6,
#  4,
#  6,
#  8,
#  4,
#  4,
#  1,
#  7,
#  3,
#  4,
#  1,
#  7,
#  6,
#  6,
#  4,
#  4,
#  6,
#  6,
#  7,
#  5,
#  1,
#  4,
#  5,
#  6,
#  7,
#  6,
#  5,
#  4,
#  7,
#  3,
#  7,
#  6,
#  3,
#  7,
#  6,
#  8,
#  5,
#  1,
#  2,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  8,
#  9,
#  3,
#  3,
#  5,
#  7,
#  7,
#  8,
#  2,
#  2,
#  3,
#  2,
#  4,
#  2,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  2,
#  3,
#  5,
#  6,
#  2,
#  1,
#  4,
#  6,
#  7,
#  5,
#  4,
#  6,
#  6,
#  6,
#  6,
#  7,
#  5,
#  7,
#  4,
#  6,
#  4,
#  6,
#  1,
#  3,
#  1,
#  5,
#  1,
#  5,
#  2,
#  1,
#  6,
#  6,
#  4,
#  7,
#  6,
#  8,
#  6,
#  5,
#  1,
#  6,
#  6,
#  6,
#  2,
#  3,
#  6,
#  6,
#  6,
#  3,
#  5,
#  3,
#  4,
#  5,
#  6,
#  6,
#  5,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  8,
#  8,
#  8,
#  6,
#  6,
#  7,
#  5,
#  4,
#  6,
#  5,
#  4,
#  7,
#  6,
#  5,
#  6,
#  4,
#  8,
#  6,
#  4,
#  7,
#  3,
#  4,
#  7,
#  5,
#  4,
#  3,
#  5,
#  6,
#  5,
#  4,
#  5,
#  5,
#  1,
#  2,
#  1,
#  5,
#  3,
#  4,
#  4,
#  5,
#  4,
#  7,
#  6,
#  4,
#  6,
#  5,
#  5,
#  6,
#  5,
#  1,
#  6,
#  3,
#  5,
#  6,
#  6,
#  5,
#  4,
#  2,
#  3,
#  1,
#  3,
#  2,
#  6,
#  6,
#  1,
#  2,
#  2,
#  7,
#  5,
#  4,
#  4,
#  5,
#  6,
#  5,
#  5,
#  1,
#  4,
#  5,
#  4,
#  2,
#  3,
#  3,
#  4,
#  6,
#  2,
#  5,
#  4,
#  7,
#  6,
#  5,
#  7,
#  6,
#  8,
#  10,
#  4,
#  4,
#  3,
#  1,
#  3,
#  2,
#  2,
#  6,
#  3,
#  5,
#  6,
#  4,
#  6,
#  4,
#  5,
#  8,
#  3,
#  8,
#  6,
#  3,
#  5,
#  4,
#  4,
#  5,
#  3,
#  2,
#  1,
#  1,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  6,
#  4,
#  6,
#  7,
#  6,
#  4,
#  5,
#  6,
#  8,
#  2,
#  4,
#  6,
#  7,
#  5,
#  4,
#  5,
#  3,
#  1,
#  3,
#  4,
#  8,
#  4,
#  2,
#  7,
#  7,
#  6,
#  3,
#  4,
#  10,
#  6,
#  5,
#  4,
#  4,
#  3,
#  4,
#  6,
#  1,
#  7,
#  5,
#  4,
#  4,
#  7,
#  3,
#  3,
#  6,
#  1,
#  5,
#  4,
#  4,
#  4,
#  5,
#  6,
#  5,
#  7,
#  4,
#  6,
#  7,
#  5,
#  6,
#  5,
#  6,
#  7,
#  10,
#  7,
#  7,
#  6,
#  4,
#  5,
#  6,
#  4,
#  3,
#  1,
#  3,
#  2,
#  7,
#  4,
#  4,
#  2,
#  4,
#  8,
#  5,
#  6,
#  4,
#  4,
#  5,
#  4,
#  7,
#  5,
#  4,
#  1,
#  3,
#  5,
#  3,
#  4,
#  2,
#  3,
#  8,
#  1,
#  8,
#  6,
#  7,
#  8,
#  3,
#  6,
#  6,
#  6,
#  10,
#  1,
#  5,
#  7,
#  3,
#  5,
#  6,
#  4,
#  5,
#  10,
#  7,
#  6,
#  6,
#  4,
#  5,
#  5,
#  6,
#  8,
#  1,
#  7,
#  8,
#  7,
#  6,
#  7,
#  8,
#  7,
#  6,
#  1,
#  3,
#  3,
#  7,
#  5,
#  4,
#  5,
#  5,
#  1,
#  7,
#  4,
#  6,
#  7,
#  4,
#  6,
#  3,
#  6,
#  2,
#  2,
#  5,
#  6,
#  5,
#  6,
#  4,
#  4,
#  1,
#  6,
#  3,
#  3,
#  4,
#  5,
#  6,
#  6,
#  5,
#  7,
#  1,
#  7,
#  7,
#  7,
#  6,
#  6,
#  5,
#  6,
#  7,
#  1,
#  3,
#  4,
#  4,
#  3,
#  6,
#  4,
#  4,
#  6,
#  4,
#  1,
#  7,
#  1,
#  4,
#  6,
#  4,
#  5,
#  2,
#  1,
#  3,
#  8,
#  7,
#  6,
#  6,
#  5,
#  7,
#  7,
#  6,
#  4,
#  5,
#  4,
#  3,
#  5,
#  6,
#  5,
#  2,
#  2,
#  2,
#  4,
#  10,
#  5,
#  4,
#  3,
#  5,
#  3,
#  6,
#  6,
#  5,
#  7,
#  5,
#  5,
#  6,
#  4,
#  6,
#  1,
#  4,
#  4,
#  3,
#  4,
#  5,
#  5,
#  4,
#  1,
#  7,
#  4,
#  4,
#  5,
#  4,
#  4,
#  5,
#  4,
#  6,
#  1,
#  7,
#  2,
#  2,
#  3,
#  4,
#  4,
#  5,
#  4,
#  9,
#  5,
#  6,
#  7,
#  7,
#  5,
#  7,
#  8,
#  4,
#  3,
#  10,
#  5,
#  5,
#  4,
#  7,
#  6,
#  7,
#  4,
#  7,
#  5,
#  4,
#  6,
#  5,
#  6,
#  5,
#  5,
#  8,
#  4,
#  6,
#  7,
#  6,
#  3,
#  4,
#  5,
#  4,
#  5,
#  4,
#  3,
#  3,
#  4,
#  7,
#  5,
#  6,
#  5,
#  7,
#  6,
#  5,
#  6,
#  4,
#  7,
#  8,
#  6,
#  7,
#  6,
#  8,
#  6,
#  7,
#  7,
#  8,
#  10,
#  7,
#  6,
#  8,
#  9,
#  7,
#  8,
#  2,
#  3,
#  4,
#  5,
#  3,
#  4,
#  3,
#  4,
#  6,
#  5,
#  5,
#  3,
#  4,
#  5,
#  4,
#  4,
#  6,
#  10,
#  5,
#  6,
#  4,
#  5,
#  5,
#  4,
#  4,
#  1,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  6,
#  7,
#  4,
#  4,
#  3,
#  3,
#  3,
#  4,
#  3,
#  7,
#  7,
#  5,
#  4,
#  5,
#  4,
#  5,
#  6,
#  3,
#  1,
#  2,
#  7,
#  3,
#  5,
#  7,
#  3,
#  3,
#  6,
#  5,
#  7,
#  8,
#  7,
#  6,
#  4,
#  5,
#  4,
#  4,
#  3,
#  3,
#  3,
#  2,
#  4,
#  1,
#  1,
#  3,
#  6,
#  6,
#  7,
#  4,
#  4,
#  2,
#  5,
#  3,
#  2,
#  4,
#  7,
#  7,
#  7,
#  7,
#  1,
#  3,
#  2,
#  1,
#  5,
#  5,
#  6,
#  5,
#  8,
#  6,
#  2,
#  6,
#  5,
#  5,
#  3,
#  4,
#  2,
#  6,
#  10,
#  9,
#  9,
#  4,
#  7,
#  8,
#  7,
#  8,
#  8,
#  9,
#  9,
#  7,
#  6,
#  2,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  2,
#  7,
#  7,
#  5,
#  1,
#  1,
#  1,
#  3,
#  7,
#  5,
#  1,
#  7,
#  4,
#  3,
#  9,
#  9,
#  9,
#  1,
#  7,
#  8,
#  4,
#  6,
#  4,
#  5,
#  7,
#  8,
#  6,
#  5,
#  5,
#  7,
#  8,
#  6,
#  5,
#  3,
#  6,
#  4,
#  7,
#  5,
#  2,
#  2,
#  5,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  4,
#  4,
#  3,
#  4,
#  7,
#  8,
#  7,
#  5,
#  5,
#  6,
#  5,
#  4,
#  5,
#  7,
#  7,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  9,
#  7,
#  7,
#  7,
#  5,
#  6,
#  7,
#  5,
#  5,
#  7,
#  6,
#  6,
#  7,
#  4,
#  3,
#  3,
#  4,
#  5,
#  5,
#  3,
#  8,
#  8,
#  5,
#  6,
#  3,
#  3,
#  4,
#  6,
#  3,
#  8,
#  7,
#  7,
#  7,
#  6,
#  7,
#  7,
#  6,
#  7,
#  2,
#  4,
#  1,
#  10,
#  3,
#  3,
#  2,
#  7,
#  7,
#  7,
#  5,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  7,
#  6,
#  7,
#  7,
#  6,
#  7,
#  5,
#  6,
#  6,
#  7,
#  7,
#  6,
#  7,
#  5,
#  6,
#  7,
#  1,
#  1,
#  ...]

# %%
'''

trlx.train(
    config=default_ilql_config(),
    samples=prompts,
    rewards=ratings,
    eval_prompts=["An astronaut riding a horse"] * 64,
)

'''
# Out:
# '\n\ntrlx.train(\n    config=default_ilql_config(),\n    samples=prompts,\n    rewards=ratings,\n    eval_prompts=["An astronaut riding a horse"] * 64,\n)\n\n'
